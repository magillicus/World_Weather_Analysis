# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitiude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a4255e0dfc9d3791796307275c241775

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | taurage
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | tura
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | misratah
# Processing Record 13 of Set 1 | ust-barguzin
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | isangel
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | cabo san lucas
# Processing Record 19 of Set 1 | cidreira
# Processing Record 20 of Set 1 | chokurdakh
# Processing Record 21 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 1 | mahebourg
# Processing Record 23 of Set 1 | pasni
# Processing Record 24 of Set 1 | cotonou
# Processing Record 25 of Set 1 | brasy
# Processing Record 26 of Set 1 | dunedin
# Processing Record 27 of Set 1 | karpathos
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 30 of Set 1 | ponta do sol
# Processing Record 31 of Set 1 | san quintin
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | didwana
# Processing Record 34 of Set 1 | brewster
# Processing Record 35 of Set 1 | katsiveli
# City not found. Skipping...
# Processing Record 36 of Set 1 | oksfjord
# Processing Record 37 of Set 1 | grindavik
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | kainantu
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | ixtapa
# Processing Record 46 of Set 1 | emmett
# Processing Record 47 of Set 1 | krasnogorodsk
# Processing Record 48 of Set 1 | saint george
# Processing Record 49 of Set 1 | vao
# Processing Record 50 of Set 1 | bam
# Processing Record 1 of Set 2 | alice springs
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | kampene
# Processing Record 6 of Set 2 | lavrentiya
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | northam
# Processing Record 9 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 2 | kaitangata
# Processing Record 12 of Set 2 | nanortalik
# Processing Record 13 of Set 2 | matay
# Processing Record 14 of Set 2 | qingdao
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | sesheke
# Processing Record 17 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | upernavik
# Processing Record 20 of Set 2 | dawson creek
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | olafsvik
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | ribeira grande
# Processing Record 25 of Set 2 | teguldet
# Processing Record 26 of Set 2 | suamico
# Processing Record 27 of Set 2 | sao joao da barra
# Processing Record 28 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 2 | arraial do cabo
# Processing Record 31 of Set 2 | bluff
# Processing Record 32 of Set 2 | atar
# Processing Record 33 of Set 2 | fairbanks
# Processing Record 34 of Set 2 | bubaque
# Processing Record 35 of Set 2 | port-gentil
# Processing Record 36 of Set 2 | bathsheba
# Processing Record 37 of Set 2 | tuatapere
# Processing Record 38 of Set 2 | kargil
# Processing Record 39 of Set 2 | telenesti
# Processing Record 40 of Set 2 | adrar
# Processing Record 41 of Set 2 | dongfeng
# Processing Record 42 of Set 2 | shchuchye
# City not found. Skipping...
# Processing Record 43 of Set 2 | kodiak
# Processing Record 44 of Set 2 | tukrah
# Processing Record 45 of Set 2 | naze
# Processing Record 46 of Set 2 | zeya
# Processing Record 47 of Set 2 | half moon bay
# Processing Record 48 of Set 2 | provideniya
# Processing Record 49 of Set 2 | longyearbyen
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | hukuntsi
# Processing Record 2 of Set 3 | sitka
# Processing Record 3 of Set 3 | atuona
# Processing Record 4 of Set 3 | inongo
# Processing Record 5 of Set 3 | mount isa
# Processing Record 6 of Set 3 | husavik
# Processing Record 7 of Set 3 | moerai
# Processing Record 8 of Set 3 | panzhihua
# Processing Record 9 of Set 3 | tanjong malim
# City not found. Skipping...
# Processing Record 10 of Set 3 | jamestown
# Processing Record 11 of Set 3 | newport
# Processing Record 12 of Set 3 | saint-pierre
# Processing Record 13 of Set 3 | cochrane
# Processing Record 14 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | makushino
# Processing Record 17 of Set 3 | praia da vitoria
# Processing Record 18 of Set 3 | miranorte
# City not found. Skipping...
# Processing Record 19 of Set 3 | norman wells
# Processing Record 20 of Set 3 | inuvik
# Processing Record 21 of Set 3 | suzu
# City not found. Skipping...
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 3 | lebu
# Processing Record 25 of Set 3 | aklavik
# Processing Record 26 of Set 3 | burnie
# Processing Record 27 of Set 3 | faanui
# Processing Record 28 of Set 3 | maba
# Processing Record 29 of Set 3 | zhigansk
# Processing Record 30 of Set 3 | cambridge
# Processing Record 31 of Set 3 | ilulissat
# Processing Record 32 of Set 3 | sola
# Processing Record 33 of Set 3 | carnarvon
# Processing Record 34 of Set 3 | airai
# Processing Record 35 of Set 3 | chaman
# Processing Record 36 of Set 3 | bilibino
# Processing Record 37 of Set 3 | pangnirtung
# Processing Record 38 of Set 3 | taltal
# Processing Record 39 of Set 3 | leningradskiy
# Processing Record 40 of Set 3 | arlit
# Processing Record 41 of Set 3 | kharabali
# Processing Record 42 of Set 3 | saint-philippe
# Processing Record 43 of Set 3 | santiago de cao
# Processing Record 44 of Set 3 | lasa
# Processing Record 45 of Set 3 | acapulco
# Processing Record 46 of Set 3 | hermanus
# Processing Record 47 of Set 3 | sao filipe
# Processing Record 48 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 3 | jalu
# Processing Record 50 of Set 3 | freudenstadt
# Processing Record 1 of Set 4 | rodas
# Processing Record 2 of Set 4 | itarema
# Processing Record 3 of Set 4 | narsaq
# Processing Record 4 of Set 4 | broken hill
# Processing Record 5 of Set 4 | angoche
# Processing Record 6 of Set 4 | chuy
# Processing Record 7 of Set 4 | seoul
# Processing Record 8 of Set 4 | adre
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | humberto de campos
# Processing Record 11 of Set 4 | troitsko-pechorsk
# Processing Record 12 of Set 4 | alamos
# Processing Record 13 of Set 4 | zhangye
# Processing Record 14 of Set 4 | takoradi
# Processing Record 15 of Set 4 | bud
# Processing Record 16 of Set 4 | nikolskoye
# Processing Record 17 of Set 4 | celestun
# Processing Record 18 of Set 4 | port macquarie
# Processing Record 19 of Set 4 | juifang
# City not found. Skipping...
# Processing Record 20 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 4 | hilo
# Processing Record 22 of Set 4 | atambua
# Processing Record 23 of Set 4 | tautira
# Processing Record 24 of Set 4 | balimo
# City not found. Skipping...
# Processing Record 25 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 4 | bundaberg
# Processing Record 27 of Set 4 | mwene-ditu
# Processing Record 28 of Set 4 | saint-georges
# Processing Record 29 of Set 4 | sarangani
# Processing Record 30 of Set 4 | ashland
# Processing Record 31 of Set 4 | bandarbeyla
# Processing Record 32 of Set 4 | torbay
# Processing Record 33 of Set 4 | les cayes
# Processing Record 34 of Set 4 | keti bandar
# Processing Record 35 of Set 4 | saint-paul
# Processing Record 36 of Set 4 | iqaluit
# Processing Record 37 of Set 4 | pritzwalk
# Processing Record 38 of Set 4 | bafra
# Processing Record 39 of Set 4 | klaksvik
# Processing Record 40 of Set 4 | bethel
# Processing Record 41 of Set 4 | san cristobal
# Processing Record 42 of Set 4 | edd
# Processing Record 43 of Set 4 | luderitz
# Processing Record 44 of Set 4 | pauini
# Processing Record 45 of Set 4 | dolores
# Processing Record 46 of Set 4 | sungairaya
# Processing Record 47 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 4 | martinsburg
# Processing Record 49 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 4 | lambarene
# Processing Record 1 of Set 5 | mogadishu
# Processing Record 2 of Set 5 | oranjemund
# Processing Record 3 of Set 5 | erdaojiang
# Processing Record 4 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 5 of Set 5 | esso
# Processing Record 6 of Set 5 | anloga
# Processing Record 7 of Set 5 | bontang
# Processing Record 8 of Set 5 | liniere
# City not found. Skipping...
# Processing Record 9 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 5 | varnamo
# Processing Record 11 of Set 5 | imeni poliny osipenko
# Processing Record 12 of Set 5 | camacha
# Processing Record 13 of Set 5 | carstairs
# Processing Record 14 of Set 5 | sebinkarahisar
# Processing Record 15 of Set 5 | vicuna
# Processing Record 16 of Set 5 | bereda
# Processing Record 17 of Set 5 | lorengau
# Processing Record 18 of Set 5 | resistencia
# Processing Record 19 of Set 5 | alyangula
# Processing Record 20 of Set 5 | ilo
# Processing Record 21 of Set 5 | kahului
# Processing Record 22 of Set 5 | saskylakh
# Processing Record 23 of Set 5 | laguna
# Processing Record 24 of Set 5 | omboue
# Processing Record 25 of Set 5 | naranjal
# Processing Record 26 of Set 5 | alta floresta
# Processing Record 27 of Set 5 | upata
# Processing Record 28 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 29 of Set 5 | harper
# Processing Record 30 of Set 5 | bac giang
# Processing Record 31 of Set 5 | tarko-sale
# Processing Record 32 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 33 of Set 5 | pevek
# Processing Record 34 of Set 5 | novopokrovka
# Processing Record 35 of Set 5 | alofi
# Processing Record 36 of Set 5 | clyde river
# Processing Record 37 of Set 5 | maniitsoq
# Processing Record 38 of Set 5 | port blair
# Processing Record 39 of Set 5 | farmington
# Processing Record 40 of Set 5 | beringovskiy
# Processing Record 41 of Set 5 | nouadhibou
# Processing Record 42 of Set 5 | vardo
# Processing Record 43 of Set 5 | diebougou
# Processing Record 44 of Set 5 | morshansk
# Processing Record 45 of Set 5 | sambava
# Processing Record 46 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 47 of Set 5 | westport
# Processing Record 48 of Set 5 | walvis bay
# Processing Record 49 of Set 5 | dalianwan
# Processing Record 50 of Set 5 | caravelas
# Processing Record 1 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 2 of Set 6 | gold coast
# Processing Record 3 of Set 6 | okhotsk
# Processing Record 4 of Set 6 | victoria
# Processing Record 5 of Set 6 | mawlaik
# Processing Record 6 of Set 6 | sao paulo de olivenca
# Processing Record 7 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 6 | boende
# Processing Record 9 of Set 6 | malanje
# Processing Record 10 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 6 | geraldton
# Processing Record 12 of Set 6 | mecca
# Processing Record 13 of Set 6 | meulaboh
# Processing Record 14 of Set 6 | hlotse
# Processing Record 15 of Set 6 | prince rupert
# Processing Record 16 of Set 6 | kashi
# Processing Record 17 of Set 6 | were ilu
# Processing Record 18 of Set 6 | hamilton
# Processing Record 19 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 6 | nome
# Processing Record 21 of Set 6 | lakes entrance
# Processing Record 22 of Set 6 | cody
# Processing Record 23 of Set 6 | bengkulu
# Processing Record 24 of Set 6 | kirakira
# Processing Record 25 of Set 6 | ostrovnoy
# Processing Record 26 of Set 6 | luebo
# Processing Record 27 of Set 6 | marawi
# Processing Record 28 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 6 | hami
# Processing Record 30 of Set 6 | lyubim
# Processing Record 31 of Set 6 | saldanha
# Processing Record 32 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 6 | sept-iles
# Processing Record 34 of Set 6 | mehamn
# Processing Record 35 of Set 6 | marrakesh
# Processing Record 36 of Set 6 | araouane
# Processing Record 37 of Set 6 | tessalit
# Processing Record 38 of Set 6 | ancud
# Processing Record 39 of Set 6 | portland
# Processing Record 40 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 6 | richards bay
# Processing Record 42 of Set 6 | labrea
# Processing Record 43 of Set 6 | kandalaksha
# Processing Record 44 of Set 6 | pangody
# Processing Record 45 of Set 6 | vanimo
# Processing Record 46 of Set 6 | chagoda
# Processing Record 47 of Set 6 | iberia
# Processing Record 48 of Set 6 | nabire
# Processing Record 49 of Set 6 | severo-kurilsk
# Processing Record 50 of Set 6 | luanda
# Processing Record 1 of Set 7 | monsey
# Processing Record 2 of Set 7 | coos bay
# Processing Record 3 of Set 7 | high level
# Processing Record 4 of Set 7 | tual
# Processing Record 5 of Set 7 | rawson
# Processing Record 6 of Set 7 | gijon
# Processing Record 7 of Set 7 | kutum
# Processing Record 8 of Set 7 | chumikan
# Processing Record 9 of Set 7 | phan thiet
# Processing Record 10 of Set 7 | egvekinot
# Processing Record 11 of Set 7 | domodossola
# Processing Record 12 of Set 7 | huarmey
# Processing Record 13 of Set 7 | uyskoye
# Processing Record 14 of Set 7 | chernushka
# Processing Record 15 of Set 7 | shahriyar
# City not found. Skipping...
# Processing Record 16 of Set 7 | santa cruz de la palma
# Processing Record 17 of Set 7 | san patricio
# Processing Record 18 of Set 7 | barrow
# Processing Record 19 of Set 7 | kasongo-lunda
# Processing Record 20 of Set 7 | emba
# Processing Record 21 of Set 7 | dharur
# Processing Record 22 of Set 7 | kruisfontein
# Processing Record 23 of Set 7 | baruun-urt
# Processing Record 24 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 7 | buraydah
# Processing Record 26 of Set 7 | baoying
# Processing Record 27 of Set 7 | omutinskoye
# City not found. Skipping...
# Processing Record 28 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 7 | padang
# Processing Record 30 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 31 of Set 7 | chernyshevskiy
# Processing Record 32 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 33 of Set 7 | tumaco
# Processing Record 34 of Set 7 | srednekolymsk
# Processing Record 35 of Set 7 | moron
# Processing Record 36 of Set 7 | nuuk
# Processing Record 37 of Set 7 | dalbandin
# Processing Record 38 of Set 7 | bambous virieux
# Processing Record 39 of Set 7 | monteagudo
# Processing Record 40 of Set 7 | souillac
# Processing Record 41 of Set 7 | dingle
# Processing Record 42 of Set 7 | sarai
# Processing Record 43 of Set 7 | boguchany
# Processing Record 44 of Set 7 | meadow lake
# Processing Record 45 of Set 7 | xiaoweizhai
# Processing Record 46 of Set 7 | livingstonia
# Processing Record 47 of Set 7 | punto fijo
# Processing Record 48 of Set 7 | yar-sale
# Processing Record 49 of Set 7 | sovetskaya gavan
# Processing Record 50 of Set 7 | burica
# City not found. Skipping...
# Processing Record 1 of Set 8 | nawabganj
# Processing Record 2 of Set 8 | monroe
# Processing Record 3 of Set 8 | forio
# Processing Record 4 of Set 8 | noumea
# Processing Record 5 of Set 8 | hasaki
# Processing Record 6 of Set 8 | fukue
# Processing Record 7 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 8 of Set 8 | cherskiy
# Processing Record 9 of Set 8 | platanos
# Processing Record 10 of Set 8 | yenagoa
# Processing Record 11 of Set 8 | tigil
# Processing Record 12 of Set 8 | valcourt
# Processing Record 13 of Set 8 | wewak
# Processing Record 14 of Set 8 | labuhan
# Processing Record 15 of Set 8 | riyadh
# Processing Record 16 of Set 8 | hobyo
# Processing Record 17 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 8 | havre-saint-pierre
# Processing Record 19 of Set 8 | clarence town
# Processing Record 20 of Set 8 | salalah
# Processing Record 21 of Set 8 | pokhara
# Processing Record 22 of Set 8 | eureka
# Processing Record 23 of Set 8 | namatanai
# Processing Record 24 of Set 8 | pringsewu
# Processing Record 25 of Set 8 | acajutla
# Processing Record 26 of Set 8 | tanda
# Processing Record 27 of Set 8 | kangalassy
# Processing Record 28 of Set 8 | flin flon
# Processing Record 29 of Set 8 | paragominas
# Processing Record 30 of Set 8 | raga
# Processing Record 31 of Set 8 | la macarena
# Processing Record 32 of Set 8 | san ramon
# Processing Record 33 of Set 8 | dikson
# Processing Record 34 of Set 8 | anantnag
# Processing Record 35 of Set 8 | daru
# Processing Record 36 of Set 8 | popondetta
# Processing Record 37 of Set 8 | scicli
# Processing Record 38 of Set 8 | kingston
# Processing Record 39 of Set 8 | talitsa
# Processing Record 40 of Set 8 | san pedro
# Processing Record 41 of Set 8 | gasa
# Processing Record 42 of Set 8 | kuva
# City not found. Skipping...
# Processing Record 43 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 8 | ust-kuyga
# Processing Record 45 of Set 8 | novopetrovskoye
# Processing Record 46 of Set 8 | madimba
# Processing Record 47 of Set 8 | poli
# Processing Record 48 of Set 8 | ulladulla
# Processing Record 49 of Set 8 | contamana
# Processing Record 50 of Set 8 | kununurra
# Processing Record 1 of Set 9 | kikwit
# Processing Record 2 of Set 9 | pangai
# Processing Record 3 of Set 9 | mitsamiouli
# Processing Record 4 of Set 9 | esperance
# Processing Record 5 of Set 9 | buala
# Processing Record 6 of Set 9 | olean
# Processing Record 7 of Set 9 | amga
# Processing Record 8 of Set 9 | codrington
# Processing Record 9 of Set 9 | bend
# Processing Record 10 of Set 9 | nikolayevsk-na-amure
# Processing Record 11 of Set 9 | zanjan
# Processing Record 12 of Set 9 | poum
# Processing Record 13 of Set 9 | yulara
# Processing Record 14 of Set 9 | seredka
# Processing Record 15 of Set 9 | kawalu
# Processing Record 16 of Set 9 | emerald
# Processing Record 17 of Set 9 | college
# Processing Record 18 of Set 9 | wanning
# Processing Record 19 of Set 9 | arkhangelsk
# Processing Record 20 of Set 9 | suzhou
# Processing Record 21 of Set 9 | urumqi
# Processing Record 22 of Set 9 | kavaratti
# Processing Record 23 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 9 | vestmannaeyjar
# Processing Record 25 of Set 9 | dali
# Processing Record 26 of Set 9 | chicama
# Processing Record 27 of Set 9 | rennes
# Processing Record 28 of Set 9 | khuzhir
# Processing Record 29 of Set 9 | muros
# Processing Record 30 of Set 9 | tortoli
# Processing Record 31 of Set 9 | sinnamary
# Processing Record 32 of Set 9 | karasburg
# Processing Record 33 of Set 9 | batemans bay
# Processing Record 34 of Set 9 | tomatlan
# Processing Record 35 of Set 9 | rameswaram
# Processing Record 36 of Set 9 | port augusta
# Processing Record 37 of Set 9 | urusha
# Processing Record 38 of Set 9 | tarakan
# Processing Record 39 of Set 9 | miles city
# Processing Record 40 of Set 9 | port lincoln
# Processing Record 41 of Set 9 | kiama
# Processing Record 42 of Set 9 | wukari
# Processing Record 43 of Set 9 | mamallapuram
# Processing Record 44 of Set 9 | maceio
# Processing Record 45 of Set 9 | lompoc
# Processing Record 46 of Set 9 | kochubey
# Processing Record 47 of Set 9 | putina
# Processing Record 48 of Set 9 | botro
# Processing Record 49 of Set 9 | hearst
# Processing Record 50 of Set 9 | chishtian mandi
# Processing Record 1 of Set 10 | boueni
# Processing Record 2 of Set 10 | bay roberts
# Processing Record 3 of Set 10 | barsovo
# Processing Record 4 of Set 10 | high prairie
# Processing Record 5 of Set 10 | davila
# Processing Record 6 of Set 10 | shangrao
# Processing Record 7 of Set 10 | dunda
# Processing Record 8 of Set 10 | kalmunai
# Processing Record 9 of Set 10 | tabou
# Processing Record 10 of Set 10 | touros
# Processing Record 11 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 12 of Set 10 | japura
# Processing Record 13 of Set 10 | coro
# Processing Record 14 of Set 10 | uvinza
# Processing Record 15 of Set 10 | severo-yeniseyskiy
# Processing Record 16 of Set 10 | jiuquan
# Processing Record 17 of Set 10 | jaisalmer
# Processing Record 18 of Set 10 | jogighopa
# Processing Record 19 of Set 10 | massakory
# Processing Record 20 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 21 of Set 10 | carutapera
# Processing Record 22 of Set 10 | telma
# Processing Record 23 of Set 10 | hailar
# Processing Record 24 of Set 10 | mackay
# Processing Record 25 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 10 | wuda
# Processing Record 27 of Set 10 | cuiluan
# Processing Record 28 of Set 10 | cockburn town
# Processing Record 29 of Set 10 | cordele
# Processing Record 30 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 31 of Set 10 | fortuna
# Processing Record 32 of Set 10 | komsomolskiy
# Processing Record 33 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 34 of Set 10 | manbij
# Processing Record 35 of Set 10 | khani
# Processing Record 36 of Set 10 | moundou
# Processing Record 37 of Set 10 | mollendo
# Processing Record 38 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 39 of Set 10 | bima
# Processing Record 40 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 41 of Set 10 | dharchula
# Processing Record 42 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 10 | kharp
# Processing Record 44 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 45 of Set 10 | eirunepe
# Processing Record 46 of Set 10 | olonets
# Processing Record 47 of Set 10 | arcani
# Processing Record 48 of Set 10 | vagur
# Processing Record 49 of Set 10 | evensk
# Processing Record 50 of Set 10 | yuancheng
# Processing Record 1 of Set 11 | srivardhan
# Processing Record 2 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 11 | asau
# Processing Record 4 of Set 11 | lashio
# Processing Record 5 of Set 11 | ihosy
# Processing Record 6 of Set 11 | saint-augustin
# Processing Record 7 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 8 of Set 11 | negombo
# Processing Record 9 of Set 11 | wonthaggi
# Processing Record 10 of Set 11 | kamenka
# Processing Record 11 of Set 11 | lata
# Processing Record 12 of Set 11 | sorochinsk
# Processing Record 13 of Set 11 | brae
# Processing Record 14 of Set 11 | lazaro cardenas
# Processing Record 15 of Set 11 | henties bay
# Processing Record 16 of Set 11 | junqueiro
# Processing Record 17 of Set 11 | yarada
# Processing Record 18 of Set 11 | santa rosa
# Processing Record 19 of Set 11 | terney
# Processing Record 20 of Set 11 | beloha
# Processing Record 21 of Set 11 | wonosobo
# Processing Record 22 of Set 11 | kiunga
# Processing Record 23 of Set 11 | zastron
# Processing Record 24 of Set 11 | ugoofaaru
# Processing Record 25 of Set 11 | coquimbo
# Processing Record 26 of Set 11 | constitucion
# Processing Record 27 of Set 11 | cassilandia
# Processing Record 28 of Set 11 | vila franca do campo
# Processing Record 29 of Set 11 | nantucket
# Processing Record 30 of Set 11 | jiexiu
# Processing Record 31 of Set 11 | mokhotlong
# Processing Record 32 of Set 11 | langarud
# Processing Record 33 of Set 11 | ahipara
# Processing Record 34 of Set 11 | vilyuysk
# Processing Record 35 of Set 11 | ossora
# Processing Record 36 of Set 11 | arman
# Processing Record 37 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 11 | mbandaka
# Processing Record 39 of Set 11 | vaasa
# Processing Record 40 of Set 11 | sadiqabad
# Processing Record 41 of Set 11 | cesena
# Processing Record 42 of Set 11 | tevriz
# Processing Record 43 of Set 11 | vanavara
# Processing Record 44 of Set 11 | beidao
# Processing Record 45 of Set 11 | viedma
# Processing Record 46 of Set 11 | inhambane
# Processing Record 47 of Set 11 | uusikaupunki
# Processing Record 48 of Set 11 | gravdal
# Processing Record 49 of Set 11 | santa maria
# Processing Record 50 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 1 of Set 12 | linxia
# Processing Record 2 of Set 12 | mangalagiri
# Processing Record 3 of Set 12 | artyom
# Processing Record 4 of Set 12 | skjervoy
# Processing Record 5 of Set 12 | licheng
# Processing Record 6 of Set 12 | te anau
# Processing Record 7 of Set 12 | shizunai
# Processing Record 8 of Set 12 | avera
# Processing Record 9 of Set 12 | khirkiya
# Processing Record 10 of Set 12 | goundi
# Processing Record 11 of Set 12 | pushkinskiye gory
# Processing Record 12 of Set 12 | puerto leguizamo
# Processing Record 13 of Set 12 | am timan
# Processing Record 14 of Set 12 | champerico
# Processing Record 15 of Set 12 | casa nova
# Processing Record 16 of Set 12 | tari
# Processing Record 17 of Set 12 | sioux lookout
# Processing Record 18 of Set 12 | hammerfest
# Processing Record 19 of Set 12 | kawhia
# Processing Record 20 of Set 12 | xining
# Processing Record 21 of Set 12 | kirksville
# Processing Record 22 of Set 12 | rondonopolis
# Processing Record 23 of Set 12 | panaba
# Processing Record 24 of Set 12 | le vauclin
# Processing Record 25 of Set 12 | torbat-e jam
# Processing Record 26 of Set 12 | abu samrah
# Processing Record 27 of Set 12 | the pas
# Processing Record 28 of Set 12 | paramonga
# Processing Record 29 of Set 12 | scarborough
# Processing Record 30 of Set 12 | khipro
# Processing Record 31 of Set 12 | rockport
# Processing Record 32 of Set 12 | junction city
# Processing Record 33 of Set 12 | mangan
# Processing Record 34 of Set 12 | gat
# Processing Record 35 of Set 12 | kushima
# Processing Record 36 of Set 12 | cayenne
# Processing Record 37 of Set 12 | prince george
# Processing Record 38 of Set 12 | helena
# Processing Record 39 of Set 12 | kavieng
# Processing Record 40 of Set 12 | dauphin
# Processing Record 41 of Set 12 | diamantino
# Processing Record 42 of Set 12 | ucluelet
# Processing Record 43 of Set 12 | hambantota
# Processing Record 44 of Set 12 | aykhal
# Processing Record 45 of Set 12 | mahanje
# Processing Record 46 of Set 12 | san jeronimo
# Processing Record 47 of Set 12 | suntar
# Processing Record 48 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 12 | porto recanati
# Processing Record 50 of Set 12 | guerrero negro
# Processing Record 1 of Set 13 | mersing
# Processing Record 2 of Set 13 | sao jose da coroa grande
# Processing Record 3 of Set 13 | tandil
# Processing Record 4 of Set 13 | whyalla
# Processing Record 5 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 13 | waipawa
# Processing Record 7 of Set 13 | praia
# Processing Record 8 of Set 13 | mafinga
# Processing Record 9 of Set 13 | salekhard
# Processing Record 10 of Set 13 | lakheri
# Processing Record 11 of Set 13 | gilbues
# Processing Record 12 of Set 13 | mount gambier
# Processing Record 13 of Set 13 | inirida
# Processing Record 14 of Set 13 | concordia
# Processing Record 15 of Set 13 | aksu
# Processing Record 16 of Set 13 | mandalgovi
# Processing Record 17 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 13 | tanout
# Processing Record 19 of Set 13 | tlahualilo
# City not found. Skipping...
# Processing Record 20 of Set 13 | hofn
# Processing Record 21 of Set 13 | gayny
# Processing Record 22 of Set 13 | dubbo
# Processing Record 23 of Set 13 | mildura
# Processing Record 24 of Set 13 | ibi
# Processing Record 25 of Set 13 | utete
# Processing Record 26 of Set 13 | lajas
# Processing Record 27 of Set 13 | waitati
# Processing Record 28 of Set 13 | china
# Processing Record 29 of Set 13 | skibbereen
# Processing Record 30 of Set 13 | solvychegodsk
# Processing Record 31 of Set 13 | iturama
# Processing Record 32 of Set 13 | la grande
# Processing Record 33 of Set 13 | mana
# Processing Record 34 of Set 13 | qaqortoq
# Processing Record 35 of Set 13 | nortelandia
# Processing Record 36 of Set 13 | manica
# Processing Record 37 of Set 13 | crystal beach
# Processing Record 38 of Set 13 | butembo
# Processing Record 39 of Set 13 | kemin
# Processing Record 40 of Set 13 | wa
# City not found. Skipping...
# Processing Record 41 of Set 13 | gumusyaka
# City not found. Skipping...
# Processing Record 42 of Set 13 | gornoye loo
# Processing Record 43 of Set 13 | bandar-e lengeh
# Processing Record 44 of Set 13 | ust-nera
# Processing Record 45 of Set 13 | kilindoni
# Processing Record 46 of Set 13 | alekseyevskaya
# Processing Record 47 of Set 13 | okha
# Processing Record 48 of Set 13 | kiruna
# Processing Record 49 of Set 13 | cuamba
# Processing Record 50 of Set 13 | salsomaggiore terme
# Processing Record 1 of Set 14 | senneterre
# Processing Record 2 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 14 | baoqing
# Processing Record 4 of Set 14 | maun
# Processing Record 5 of Set 14 | jhang
# Processing Record 6 of Set 14 | rakhya
# City not found. Skipping...
# Processing Record 7 of Set 14 | zalantun
# Processing Record 8 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 14 | lundazi
# Processing Record 10 of Set 14 | gwadar
# Processing Record 11 of Set 14 | belmonte
# Processing Record 12 of Set 14 | sabha
# Processing Record 13 of Set 14 | itamaraca
# Processing Record 14 of Set 14 | aasiaat
# Processing Record 15 of Set 14 | eregli
# Processing Record 16 of Set 14 | kaeo
# Processing Record 17 of Set 14 | chavakkad
# Processing Record 18 of Set 14 | ikongo
# Processing Record 19 of Set 14 | guiratinga
# Processing Record 20 of Set 14 | littleton
# Processing Record 21 of Set 14 | talara
# Processing Record 22 of Set 14 | byron bay
# Processing Record 23 of Set 14 | antofagasta
# Processing Record 24 of Set 14 | amurzet
# Processing Record 25 of Set 14 | lagoa
# Processing Record 26 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 27 of Set 14 | yatou
# Processing Record 28 of Set 14 | pafos
# Processing Record 29 of Set 14 | port hedland
# Processing Record 30 of Set 14 | miri
# Processing Record 31 of Set 14 | novobirilyussy
# Processing Record 32 of Set 14 | berlevag
# Processing Record 33 of Set 14 | nikolayevka
# Processing Record 34 of Set 14 | manavalakurichi
# Processing Record 35 of Set 14 | shingu
# Processing Record 36 of Set 14 | saint-joseph
# Processing Record 37 of Set 14 | niksar
# Processing Record 38 of Set 14 | mpika
# Processing Record 39 of Set 14 | urucara
# Processing Record 40 of Set 14 | male
# Processing Record 41 of Set 14 | port hardy
# Processing Record 42 of Set 14 | pop
# Processing Record 43 of Set 14 | normandin
# Processing Record 44 of Set 14 | merthyr tydfil
# Processing Record 45 of Set 14 | santa cruz
# Processing Record 46 of Set 14 | saint-ambroise
# Processing Record 47 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 14 | tambacounda
# Processing Record 49 of Set 14 | amparafaravola
# Processing Record 50 of Set 14 | inca
# Processing Record 1 of Set 15 | fort dodge
# Processing Record 2 of Set 15 | novospasskoye
# Processing Record 3 of Set 15 | marihatag
# Processing Record 4 of Set 15 | manaure
# Processing Record 5 of Set 15 | aloleng
# Processing Record 6 of Set 15 | teguise
# Processing Record 7 of Set 15 | la ronge
# Processing Record 8 of Set 15 | nanakuli
# Processing Record 9 of Set 15 | smithers
# Processing Record 10 of Set 15 | birao
# Processing Record 11 of Set 15 | linqiong
# Processing Record 12 of Set 15 | kensington
# Processing Record 13 of Set 15 | bayan
# Processing Record 14 of Set 15 | melbu
# Processing Record 15 of Set 15 | pisco
# Processing Record 16 of Set 15 | kevsala
# Processing Record 17 of Set 15 | kankon
# Processing Record 18 of Set 15 | catuday
# Processing Record 19 of Set 15 | tazovskiy
# Processing Record 20 of Set 15 | mareeba
# Processing Record 21 of Set 15 | east wenatchee bench
# Processing Record 22 of Set 15 | alihe
# Processing Record 23 of Set 15 | ozernovskiy
# Processing Record 24 of Set 15 | chikola
# Processing Record 25 of Set 15 | christchurch
# Processing Record 26 of Set 15 | yarmouth
# Processing Record 27 of Set 15 | paamiut
# Processing Record 28 of Set 15 | yaan
# Processing Record 29 of Set 15 | ipubi
# Processing Record 30 of Set 15 | huanren
# Processing Record 31 of Set 15 | parana
# Processing Record 32 of Set 15 | ojinaga
# Processing Record 33 of Set 15 | havelock
# Processing Record 34 of Set 15 | port keats
# Processing Record 35 of Set 15 | kwinana
# Processing Record 36 of Set 15 | sokolo
# Processing Record 37 of Set 15 | birjand
# Processing Record 38 of Set 15 | mariental
# Processing Record 39 of Set 15 | grande-riviere
# City not found. Skipping...
# Processing Record 40 of Set 15 | kota belud
# Processing Record 41 of Set 15 | sistranda
# Processing Record 42 of Set 15 | vallenar
# Processing Record 43 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 44 of Set 15 | pemba
# Processing Record 45 of Set 15 | robertsport
# Processing Record 46 of Set 15 | tiznit
# Processing Record 47 of Set 15 | konin
# Processing Record 48 of Set 15 | boguchar
# Processing Record 49 of Set 15 | miraflores
# Processing Record 50 of Set 15 | coihaique
# Processing Record 1 of Set 16 | garissa
# Processing Record 2 of Set 16 | bar harbor
# Processing Record 3 of Set 16 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 16 | potsdam
# Processing Record 5 of Set 16 | barguzin
# Processing Record 6 of Set 16 | safaga
# Processing Record 7 of Set 16 | ambunti
# Processing Record 8 of Set 16 | rongcheng
# Processing Record 9 of Set 16 | the valley
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Tasiilaq  65.6145  -37.6368     30.36        80          99
# 1       Mataura -46.1927  168.8643     65.48        39           4
# 2     Busselton -33.6500  115.3333     65.05        53           0
# 3         Kapaa  22.0752 -159.3190     71.92        82          90
# 4       Taurage  55.2522   22.2897      9.05        94          16
# 5   New Norfolk -42.7826  147.0587     55.71        54         100
# 6  Puerto Ayora  -0.7393  -90.3518     69.13        82          55
# 7          Tura  25.5198   90.2201     61.12        95          14
# 8    Bredasdorp -34.5322   20.0403     51.28        80           8
# 9   East London -33.0153   27.9116     65.64        84          77
#
#    Wind Speed Country   Current Description
# 0        7.31      GL       overcast clouds
# 1        1.68      NZ             clear sky
# 2       18.63      AU             clear sky
# 3       16.11      US  heavy intensity rain
# 4        4.18      LT            few clouds
# 5        1.99      AU       overcast clouds
# 6        8.61      EC         broken clouds
# 7        3.02      IN            few clouds
# 8        3.18      ZA             clear sky
# 9        8.46      ZA            light rain

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Assign new column order as the corrected DataFrame headers
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Tasiilaq      GL  65.6145  -37.6368     30.36        80          99
# 1       Mataura      NZ -46.1927  168.8643     65.48        39           4
# 2     Busselton      AU -33.6500  115.3333     65.05        53           0
# 3         Kapaa      US  22.0752 -159.3190     71.92        82          90
# 4       Taurage      LT  55.2522   22.2897      9.05        94          16
# 5   New Norfolk      AU -42.7826  147.0587     55.71        54         100
# 6  Puerto Ayora      EC  -0.7393  -90.3518     69.13        82          55
# 7          Tura      IN  25.5198   90.2201     61.12        95          14
# 8    Bredasdorp      ZA -34.5322   20.0403     51.28        80           8
# 9   East London      ZA -33.0153   27.9116     65.64        84          77
#
#    Wind Speed   Current Description
# 0        7.31       overcast clouds
# 1        1.68             clear sky
# 2       18.63             clear sky
# 3       16.11  heavy intensity rain
# 4        4.18            few clouds
# 5        1.99       overcast clouds
# 6        8.61         broken clouds
# 7        3.02            few clouds
# 8        3.18             clear sky
# 9        8.46            light rain

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
